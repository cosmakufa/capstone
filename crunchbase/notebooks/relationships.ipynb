# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv('../data/cb_relationships.csv')

# %%
df.head().T
# Out:
#                                                         0  \
# id                                                      1
# relationship_id                                         1
# person_object_id                                      p:2
# relationship_object_id                                c:1
# start_at                                              NaN
# end_at                                                NaN
# is_past                                                 0
# sequence                                                8
# title                   Co-Founder/CEO/Board of Directors
# created_at                            2007-05-25 07:03:54
# updated_at                            2013-06-03 09:58:46
#
#                                           1                    2  \
# id                                        2                    3
# relationship_id                           2                    3
# person_object_id                        p:3                  p:4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402878 entries, 0 to 402877
# Data columns (total 11 columns):
# id                        402878 non-null int64
# relationship_id           402878 non-null int64
# person_object_id          402878 non-null object
# relationship_object_id    402878 non-null object
# start_at                  206995 non-null object
# end_at                    101046 non-null object
# is_past                   402878 non-null int64
# sequence                  402878 non-null int64
# title                     389534 non-null object
# created_at                402878 non-null object
# updated_at                402878 non-null object
# dtypes: int64(4), object(7)
# memory usage: 33.8+ MB

# %%
list(df.columns)
# Out:
# ['id',
#  'relationship_id',
#  'person_object_id',
#  'relationship_object_id',
#  'start_at',
#  'end_at',
#  'is_past',
#  'sequence',
#  'title',
#  'created_at',
#  'updated_at']

# %%
df['title'].value_counts()
# Out:
# CEO                                                      20454
# Founder                                                  14402
# Co-Founder                                                9856
# Board Member                                              8584
# CTO                                                       7880
# Board of Directors                                        7464
# Director                                                  7107
# CFO                                                       5524
# President                                                 5409
# Managing Director                                         4464
# Partner                                                   4433
# Advisor                                                   4318
# COO                                                       3995
# Co-founder                                                3826
# Founder & CEO                                             3059
# ...

# %%
removed = [
 'entity_type',
 'entity_id',
 'parent_id',
 'name',
 
 'permalink',



 'closed_at',

 'homepage_url',
 'twitter_username',
 'logo_url',
 'logo_width',
 'logo_height',
 'short_description',
 'description',
 

 

 'first_investment_at',
 'last_investment_at',
 'investment_rounds',
 'invested_companies',
 'first_funding_at',
 'last_funding_at',
 'funding_rounds',
 'funding_total_usd',
 'first_milestone_at',
 'last_milestone_at',
 'milestones',
 'relationships',
 'created_by',
 'created_at',
 'updated_at']
keep = [x for x in list(df.columns) if x not in removed]
df = df[keep]
df.head().T
# Out:
#                           0         1        2      3             4
# id                        1         2        3      4             5
# object_id               p:2       p:3      p:4    p:5           p:6
# first_name              Ben     Kevin     Raju    Ian         Kevin
# last_name           Elowitz  Flaherty  Vegesna  Wenig          Rose
# birthplace              NaN       NaN      NaN    NaN   Redding, CA
# affiliation_name  Blue Nile  Wetpaint     Zoho   Zoho  i/o Ventures

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv('../data/cb_objects.csv')
# Out:
# /Users/cosmakufa/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (3,7,9,10,17,18,21,22,23,25,26,29,30,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head().T
# Out:
#                                                                      0  \
# id                                                                 c:1
# entity_type                                                    Company
# entity_id                                                            1
# parent_id                                                          NaN
# name                                                          Wetpaint
# normalized_name                                               wetpaint
# permalink                                            /company/wetpaint
# category_code                                                      web
# status                                                       operating
# founded_at                                                  2005-10-17
# closed_at                                                          NaN
# domain                                                wetpaint-inc.com
# homepage_url                                   http://wetpaint-inc.com
# twitter_username                                       BachelrWetpaint
# logo_url             http://s3.amazonaws.com/crunchbase_prod_assets...
# logo_width                                                         401
# logo_height                                                         54
# short_description                                                  NaN
# description                                Technology Platform Company
# overview             Wetpaint is a technology platform company that...
# tag_list             wiki, seattle, elowitz, media-industry, media-...
# country_code                                                       USA
# state_code                                                          WA
# city                                                           Seattle
# region                                                         Seattle
# first_investment_at                                                NaN
# last_investment_at                                                 NaN
# investment_rounds                                                  NaN
# invested_companies                                                 NaN
# first_funding_at                                            2005-10-01
# last_funding_at                                             2008-05-19
# funding_rounds                                                       3
# funding_total_usd                                            3.975e+07
# first_milestone_at                                          2010-09-05
# last_milestone_at                                           2013-09-18
# milestones                                                           5
# relationships                                                       17
# created_by                                            initial-importer
# created_at                                         2007-05-25 06:51:27
# updated_at                                         2013-04-13 03:29:00
#
#                                                                      1  \
# id                                                                c:10
# entity_type                                                    Company
# entity_id                                                           10
# parent_id                                                          NaN
# name                                                           Flektor
# normalized_name                                                flektor
# permalink                                             /company/flektor
# category_code                                              games_video
# status                                                        acquired
# founded_at                                                         NaN
# closed_at                                                          NaN
# domain                                                     flektor.com
# homepage_url                                    http://www.flektor.com
# twitter_username                                                   NaN
# logo_url             http://s3.amazonaws.com/crunchbase_prod_assets...
# logo_width                                                         186
# logo_height                                                         85
# short_description                                                  NaN
# description                                                        NaN
# overview             Flektor is a rich-media mash-up platform that ...
# tag_list                                         flektor, photo, video
# country_code                                                       USA
# state_code                                                          CA
# city                                                       Culver City
# region                                                     Los Angeles
# first_investment_at                                                NaN
# last_investment_at                                                 NaN
# investment_rounds                                                  NaN
# invested_companies                                                 NaN
# first_funding_at                                                   NaN
# last_funding_at                                                    NaN
# funding_rounds                                                     NaN
# funding_total_usd                                                  NaN
# first_milestone_at                                                 NaN
# last_milestone_at                                                  NaN
# milestones                                                         NaN
# relationships                                                        6
# created_by                                            initial-importer
# created_at                                         2007-05-31 21:11:51
# updated_at                                         2008-05-23 23:23:14
#
#                                                                      2  \
# id                                                               c:100
# entity_type                                                    Company
# entity_id                                                          100
# parent_id                                                          NaN
# name                                                             There
# normalized_name                                                  there
# permalink                                               /company/there
# category_code                                              games_video
# status                                                        acquired
# founded_at                                                         NaN
# closed_at                                                          NaN
# domain                                                       there.com
# homepage_url                                      http://www.there.com
# twitter_username                                                   NaN
# logo_url             http://s3.amazonaws.com/crunchbase_prod_assets...
# logo_width                                                         107
# logo_height                                                         34
# short_description                                                  NaN
# description                                                        NaN
# overview             There.com is an online virtual world where any...
# tag_list                                    virtualworld, there, teens
# country_code                                                       USA
# state_code                                                          CA
# city                                                         San Mateo
# region                                                          SF Bay
# first_investment_at                                                NaN
# last_investment_at                                                 NaN
# investment_rounds                                                  NaN
# invested_companies                                                 NaN
# first_funding_at                                                   NaN
# last_funding_at                                                    NaN
# funding_rounds                                                     NaN
# funding_total_usd                                                  NaN
# first_milestone_at                                          2003-02-01
# last_milestone_at                                           2011-09-23
# milestones                                                           4
# relationships                                                       12
# created_by                                            initial-importer
# created_at                                         2007-08-06 23:52:45
# updated_at                                         2013-11-04 02:09:48
#
#                                                                      3  \
# id                                                             c:10000
# entity_type                                                    Company
# entity_id                                                        10000
# parent_id                                                          NaN
# name                                                           MYWEBBO
# normalized_name                                                mywebbo
# permalink                                             /company/mywebbo
# category_code                                          network_hosting
# status                                                       operating
# founded_at                                                  2008-07-26
# closed_at                                                          NaN
# domain                                                     mywebbo.com
# homepage_url                                    http://www.mywebbo.com
# twitter_username                                                   NaN
# logo_url                                                           NaN
# logo_width                                                         NaN
# logo_height                                                        NaN
# short_description                                                  NaN
# description                                                        NaN
# overview             BRAND NEW ONLINE SOCIAL NETWORKING WEBSITE,FOR...
# tag_list             social-network, new, website, web, friends, ch...
# country_code                                                       NaN
# state_code                                                         NaN
# city                                                               NaN
# region                                                         unknown
# first_investment_at                                                NaN
# last_investment_at                                                 NaN
# investment_rounds                                                  NaN
# invested_companies                                                 NaN
# first_funding_at                                                   NaN
# last_funding_at                                                    NaN
# funding_rounds                                                     NaN
# funding_total_usd                                                  NaN
# first_milestone_at                                                 NaN
# last_milestone_at                                                  NaN
# milestones                                                         NaN
# relationships                                                      NaN
# created_by                                                         NaN
# created_at                                         2008-08-24 16:51:57
# updated_at                                         2008-09-06 14:19:18
#
#                                                                      4
# id                                                             c:10001
# entity_type                                                    Company
# entity_id                                                        10001
# parent_id                                                          NaN
# name                                                THE Movie Streamer
# normalized_name                                     the movie streamer
# permalink                                  /company/the-movie-streamer
# category_code                                              games_video
# status                                                       operating
# founded_at                                                  2008-07-26
# closed_at                                                          NaN
# domain                                            themoviestreamer.com
# homepage_url                               http://themoviestreamer.com
# twitter_username                                                   NaN
# logo_url             http://s3.amazonaws.com/crunchbase_prod_assets...
# logo_width                                                         200
# logo_height                                                         74
# short_description                                                  NaN
# description                                                        NaN
# overview             This company shows free movies online on their...
# tag_list             watch, full-length, moives, online, for, free,...
# country_code                                                       NaN
# state_code                                                         NaN
# city                                                               NaN
# region                                                         unknown
# first_investment_at                                                NaN
# last_investment_at                                                 NaN
# investment_rounds                                                  NaN
# invested_companies                                                 NaN
# first_funding_at                                                   NaN
# last_funding_at                                                    NaN
# funding_rounds                                                     NaN
# funding_total_usd                                                  NaN
# first_milestone_at                                                 NaN
# last_milestone_at                                                  NaN
# milestones                                                         NaN
# relationships                                                      NaN
# created_by                                                         NaN
# created_at                                         2008-08-24 17:10:34
# updated_at                                         2008-09-06 14:19:18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462651 entries, 0 to 462650
# Data columns (total 40 columns):
# id                     462651 non-null object
# entity_type            462651 non-null object
# entity_id              462651 non-null int64
# parent_id              27715 non-null object
# name                   462649 non-null object
# normalized_name        462620 non-null object
# permalink              462651 non-null object
# category_code          123186 non-null object
# status                 462651 non-null object
# founded_at             100441 non-null object
# closed_at              2809 non-null object
# domain                 174942 non-null object
# homepage_url           174942 non-null object
# twitter_username       126089 non-null object
# logo_url               208850 non-null object
# logo_width             208850 non-null float64
# logo_height            208850 non-null float64
# short_description      7617 non-null object
# description            95005 non-null object
# overview               235235 non-null object
# tag_list               106496 non-null object
# country_code           95043 non-null object
# state_code             54760 non-null object
# city                   90684 non-null object
# region                 462651 non-null object
# first_investment_at    16956 non-null object
# last_investment_at     16956 non-null object
# investment_rounds      16986 non-null float64
# invested_companies     16986 non-null float64
# first_funding_at       31507 non-null object
# last_funding_at        31507 non-null object
# funding_rounds         31707 non-null float64
# funding_total_usd      27874 non-null float64
# first_milestone_at     100358 non-null object
# last_milestone_at      100358 non-null object
# milestones             100358 non-null float64
# relationships          337847 non-null float64
# created_by             339486 non-null object
# created_at             462591 non-null object
# updated_at             462651 non-null object
# dtypes: float64(8), int64(1), object(31)
# memory usage: 141.2+ MB

# %%
list(df.columns)
# Out:
# ['id',
#  'entity_type',
#  'entity_id',
#  'parent_id',
#  'name',
#  'normalized_name',
#  'permalink',
#  'category_code',
#  'status',
#  'founded_at',
#  'closed_at',
#  'domain',
#  'homepage_url',
#  'twitter_username',
#  'logo_url',
#  'logo_width',
#  'logo_height',
#  'short_description',
#  'description',
#  'overview',
#  'tag_list',
#  'country_code',
#  'state_code',
#  'city',
#  'region',
#  'first_investment_at',
#  'last_investment_at',
#  'investment_rounds',
#  'invested_companies',
#  'first_funding_at',
#  'last_funding_at',
#  'funding_rounds',
#  'funding_total_usd',
#  'first_milestone_at',
#  'last_milestone_at',
#  'milestones',
#  'relationships',
#  'created_by',
#  'created_at',
#  'updated_at']

# %%
removed = [
 'entity_type',
 'entity_id',
 'parent_id',
 'name',
 
 'permalink',



 'closed_at',

 'homepage_url',
 'twitter_username',
 'logo_url',
 'logo_width',
 'logo_height',
 'short_description',
 'description',
 

 

 'first_investment_at',
 'last_investment_at',
 'investment_rounds',
 'invested_companies',
 'first_funding_at',
 'last_funding_at',
 'funding_rounds',
 'funding_total_usd',
 'first_milestone_at',
 'last_milestone_at',
 'milestones',
 'relationships',
 'created_by',
 'created_at',
 'updated_at']
keep = [x for x in list(df.columns) if x not in removed]
df = df[keep]
df.head().T
# Out:
#                                                                  0  \
# id                                                             c:1
# normalized_name                                           wetpaint
# category_code                                                  web
# status                                                   operating
# founded_at                                              2005-10-17
# domain                                            wetpaint-inc.com
# overview         Wetpaint is a technology platform company that...
# tag_list         wiki, seattle, elowitz, media-industry, media-...
# country_code                                                   USA
# state_code                                                      WA
# city                                                       Seattle
# region                                                     Seattle
#
#                                                                  1  \
# id                                                            c:10
# normalized_name                                            flektor
# category_code                                          games_video
# status                                                    acquired
# founded_at                                                     NaN
# domain                                                 flektor.com
# overview         Flektor is a rich-media mash-up platform that ...
# tag_list                                     flektor, photo, video
# country_code                                                   USA
# state_code                                                      CA
# city                                                   Culver City
# region                                                 Los Angeles
#
#                                                                  2  \
# id                                                           c:100
# normalized_name                                              there
# category_code                                          games_video
# status                                                    acquired
# founded_at                                                     NaN
# domain                                                   there.com
# overview         There.com is an online virtual world where any...
# tag_list                                virtualworld, there, teens
# country_code                                                   USA
# state_code                                                      CA
# city                                                     San Mateo
# region                                                      SF Bay
#
#                                                                  3  \
# id                                                         c:10000
# normalized_name                                            mywebbo
# category_code                                      network_hosting
# status                                                   operating
# founded_at                                              2008-07-26
# domain                                                 mywebbo.com
# overview         BRAND NEW ONLINE SOCIAL NETWORKING WEBSITE,FOR...
# tag_list         social-network, new, website, web, friends, ch...
# country_code                                                   NaN
# state_code                                                     NaN
# city                                                           NaN
# region                                                     unknown
#
#                                                                  4
# id                                                         c:10001
# normalized_name                                 the movie streamer
# category_code                                          games_video
# status                                                   operating
# founded_at                                              2008-07-26
# domain                                        themoviestreamer.com
# overview         This company shows free movies online on their...
# tag_list         watch, full-length, moives, online, for, free,...
# country_code                                                   NaN
# state_code                                                     NaN
# city                                                           NaN
# region                                                     unknown

# %%
keep
# Out:
# ['id',
#  'normalized_name',
#  'category_code',
#  'status',
#  'founded_at',
#  'domain',
#  'overview',
#  'tag_list',
#  'country_code',
#  'state_code',
#  'city',
#  'region']

# %%
keep

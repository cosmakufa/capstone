# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_degrees = pd.read_csv('data/cb_degrees.csv')

# %%
df_degrees.head().T
# Out:
#                                 0                                 1  \
# id                              1                                 2
# object_id                  p:6117                            p:6136
# degree_type                   MBA                                BA
# subject                       NaN                   English, French
# institution                   NaN  Washington University, St. Louis
# graduated_at                  NaN                        1990-01-01
# created_at    2008-02-19 03:17:36               2008-02-19 17:58:31
# updated_at    2008-02-19 03:17:36               2008-02-25 00:23:55
#
#                                 2                        3  \
# id                              3                        4
# object_id                  p:6136                   p:6005
# degree_type                    MS                       MS
# subject        Mass Communication      Internet Technology
# ...

# %%
df_degrees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109610 entries, 0 to 109609
# Data columns (total 8 columns):
# id              109610 non-null int64
# object_id       109610 non-null object
# degree_type     98392 non-null object
# subject         81298 non-null object
# institution     109555 non-null object
# graduated_at    58054 non-null object
# created_at      109610 non-null object
# updated_at      109610 non-null object
# dtypes: int64(1), object(7)
# memory usage: 6.7+ MB

# %% [markdown]
# nont all of the columns have information about degree-type, but a high amount of information about institution. do not have a lot information about when people graduated.

# %%
len(df_degrees['institution'].unique())
# Out:
# 21068

# %%
df_degrees['institution'].value_counts(1)
# Out:
# Stanford University                                    0.027292
# Harvard Business School                                0.017334
# Harvard University                                     0.014431
# University of California, Berkeley                     0.013473
# Cornell University                                     0.009511
# Massachusetts Institute of Technology (MIT)            0.008909
# University of Pennsylvania                             0.008799
# University of Michigan                                 0.008215
# Yale University                                        0.006654
# Stanford University Graduate School of Business        0.006645
# Columbia University                                    0.006609
# Duke University                                        0.006015
# Princeton University                                   0.005869
# Tel Aviv University                                    0.005687
# Northwestern University                                0.005458
# ...

# %% [markdown]
# just analyzed degree information, saw that some in depth might be needed because mit is under two names, and so might need to check information about other colleges as well.

# %%
len(df_degrees['subject'].unique())
# Out:
# 20051

# %%
subjects = set()
for entry in  df_degrees['subject']:
    if isinstance(entry, str):
        subs = entry.split(",")
        for sub in  subs:
            if isinstance(sub, str):
                subjects.add(sub.lower().strip())

# %%
len(subjects)
# Out:
# 16751

# %%
subjects
# Out:
# {'',
#  'economics of financial markets',
#  'entrepreneurs',
#  'english language and literature/letters',
#  'programming (c++',
#  'physisc',
#  'english lit',
#  'energy focus',
#  'international studies',
#  'technological innovation',
#  'chemistry and philosophy',
#  'industrial engineering & management science',
#  'health administration & policy',
#  'design & communication',
#  'interface',
#  'business/ accounting',
#  'information management & technology',
#  'medical intern and resident',
#  'antitrust',
#  'public relations / communications',
#  'foundation art',
#  'cultural history of war',
#  'system design',
#  'epidemiology',
#  'systems eng. & operations research',
#  'da2i (développement et administration de site internet et intranet)',
#  'biology and literature',
#  'mathematics and quantitative economics',
#  'electronic engineering technology',
#  'gpa: 90 (with excellence',
#  'government',
#  'manufacturing systems engineering',
#  'pgce secondary ict',
# ...

# %% [markdown]
# like we saw about information from degrees, it seems feature engineering will be required as well for information about subjects as some users inputted their subject in a foreign language. while others have different names for different degrees/ have specialized degrees

# %%
len(df_degrees['degree_type'].unique())
# Out:
# 7149

# %%
df_degrees.groupby('degree_type').count()['id'].plot(kind='bar', figsize=(20,10));

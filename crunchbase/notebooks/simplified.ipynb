# %%
from src.functions import *

# %%
(X,y, y_proba)= current_flow()
# Out:
# /Users/cosmakufa/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2910: DtypeWarning: Columns (3,7,9,10,17,18,21,22,23,25,26,29,30,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4440 entries, c:37547 to c:142266
# Data columns (total 7 columns):
# id                    4440 non-null float64
# investment_rounds     4440 non-null float64
# invested_companies    4440 non-null float64
# funding_rounds        4440 non-null float64
# funding_total_usd     4440 non-null float64
# milestones            4440 non-null float64
# relationships         4440 non-null float64
# dtypes: float64(7)
# memory usage: 277.5+ KB

# %%
y.value_counts()
# Out:
# 1    3504
# 0     936
# Name: target, dtype: int64

# %%
X.head(20)
# Out:
#                   id  investment_rounds  invested_companies  funding_rounds  \
# c:37547   631.168946           3.322857                2.86        1.750383
# c:188724  631.168946           3.322857                2.86        1.750383
# c:178793  631.168946           3.322857                2.86        2.000000
# c:13403   631.168946           1.000000                1.00        1.750383
# c:6141    631.168946           3.322857                2.86        1.000000
# c:62974   631.168946           3.322857                2.86        1.750383
# c:211585  631.168946           3.322857                2.86        1.750383
# c:26342   631.168946           3.322857                2.86        1.000000
# c:64033   631.168946           3.322857                2.86        1.750383
# c:54260   631.168946           3.322857                2.86        1.000000
# c:12512   631.168946           3.322857                2.86        1.750383
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_plot, y_plot = my_roc_curve(y, y_proba)
plt.plot(x_plot,y_plot['f1'], label="f1");
plt.plot(x_plot,y_plot['precision'], label="precision");
plt.plot(x_plot,y_plot['recall'], label="recall");
plt.legend();
# Out:
# /Users/cosmakufa/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/cosmakufa/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
